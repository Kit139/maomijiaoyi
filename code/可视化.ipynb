# %%
import pandas as pd 
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 导入数据

# %%
cat_kind = pd.read_csv('../data/cat_kind.csv')
cat_kind.head(1)
# Out:
#     品种         参考价格 中文学名          别名     祖先    分布区域 原产地  体型 原始用途 今日用途  分组  \
# 0  布偶猫  6000-20000元  布偶猫  布娃娃猫,布拉多尔猫  白色长毛猫  英国、中国、  美国  大型  宠物猫  宠物猫 NaN
#
#      身高   体重   寿命                                                 整体  毛发  \
# 0  30CM  9KG  15年  布偶猫，又称“布拉多尔（Ragdoll）”，发源于美国，是一种杂交品种宠物猫。是现存体型最大... NaN
#
#                                                   颜色  \
# 0  1、海豹色（Seal ）2、蓝色（Blue） 3、巧克力色（Chocolate）4、丁香色（...
#
#                                                   头部  \
# 0  在布偶猫还没有被广受推崇时，大家把大头圆脸作为判断猫咪是否可爱的标准，不过随着布偶猫的横空出...
#
#                                                   眼睛  \
# 0  布偶猫明亮的蓝色双眼似乎能直达你的心灵，如果仔细观察，你会发现布偶猫的眼睛是微微上扬的，是猫...
#
#                          耳朵                                    鼻子          尾巴  \
# 0  大小中等，基部宽，间距大，轻轻向前倾，耳间呈形。  中等长度的鼻子，有些布偶猫的鼻子上略有凹陷，下巴则跟上唇和鼻子为一直线。  长且拥有丰富的毛量。
#
#     胸部     颈部       前驱       后驱  \
# 0  NaN  粗且强壮。  前腿的毛较短，  前腿的毛较短，
#
#                                                 基本信息      FCI标准  \
# 0  布偶猫的品种介绍                                      ...  布偶猫的FCI标准
#
#                                                 性格特点  \
# 0  布偶猫的性格特点布偶猫以其安静温柔的性格广受喜爱，不管是对于主人，还是对于陌生人，它们都非常...
#
#                                                 生活习性  \
# 0  布偶猫的生活习性布偶猫异常温柔，较适宜室内饲养。一般应为它们做绝育并提供适当的生活环境，例如...
#
#                                                优点/缺点  \
# 0  布偶猫的优点缺点布偶猫不适合在户外生活游戏，它们更适应在室内玩耍生活。它们非常乐意与家人生活...
#
#                                                 喂养方法  \
# 0  布偶猫的喂养方法1、布偶猫是适合在室内饲养的猫咪，所以家里的养猫设备最好齐全，例如猫抓板、猫...
#
#                                                 鉴别挑选
# 0  布偶猫的鉴别挑选1、评估你的猫猫的颜色。布偶猫猫有不同的颜色和花色类型。颜色有蓝色、巧克力色...

# %%
cat_info = pd.read_csv('../data/cat_info.csv',encoding='gbk')
cat_info.head(1)
# Out:
#        地区     商家名称                        标题      价格   浏览次数  卖家承诺 在售只数   年龄  \
# 0  北京/石景山  猫舍:故乡梨花  出售纯种加菲猫 布偶猫 无毛猫 缅因猫 矮脚猫等  2100.0  255.0  正规商家   8只  3个月
#
#       品种    预防  联系人          联系电话      异地运费 是否纯种  猫咪性别  驱虫情况 猫咪年龄    能否视频  \
# 0  高地折耳猫  2针疫苗  张小姐  1.811609e+10  包运费！签协议！    是  公母都有  2针疫苗  3个月  可视频看猫咪
#
#                                                   链接
# 0  http://www.maomijiaoyi.com/index.php?/chanpinx...

# %% [markdown]
# # 都有哪些品种，词云图

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType
from pyecharts.globals import ThemeType


words = [(i,1) for i in cat_kind['品种'].unique()]
c = (
    WordCloud(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", words,shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
)
c.render('../output/猫猫品种.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="4a0957565e0643819faa16fe8f1c9fae" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_4a0957565e0643819faa16fe8f1c9fae = echarts.init(
#                     document.getElementById('4a0957565e0643819faa16fe8f1c9fae'), 'light', {renderer: 'canvas'});
#                 var option_4a0957565e0643819faa16fe8f1c9fae = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5e03\u5076\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,150,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a0\u83f2\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,137,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u6e10\u5c42",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,127,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u77ed\u84dd\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,84,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u77ed\u84dd\u767d",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,105,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u56fd\u77ed\u6bdb\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,105,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8e\u56fd\u77ed\u6bdb\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,60,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82cf\u683c\u5170\u6298\u8033\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,24,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u94f6\u6e10\u5c42",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,127,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f02\u56fd\u77ed\u6bdb\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,138,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b5f\u4e70\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,147,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u66b9\u7f57\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,20,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b5f\u52a0\u62c9\u8c79\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,79,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f05\u56e0\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,160,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u5409\u62c9\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,120,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e0\u6bdb\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,134,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ad8\u5730\u6298\u8033\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,77,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u66fc\u57fa\u5eb7\u77ee\u811a\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,77,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ce2\u65af\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,71,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6a58\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,58,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u963f\u6bd4\u897f\u5c3c\u4e9a\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,91,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u6587\u5377\u6bdb\u732b",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,60,154)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],

# %% [markdown]
# # 原产地，世界地图

# %%
chandi = cat_kind['原产地'].value_counts().reset_index()
def countryName(s):
    if s == '英国':
        return 'United Kingdom'
    if s == '美国':
        return 'United States'
    if s == '苏格兰':
        return 'Ireland'
    if s == '加拿大':
        return 'Canada'
    if s == '古埃及':
        return 'Egypt'
    if s == '泰国':
        return 'Thailand'
    if s == '阿富汗':
        return 'Afghanistan'
    if s == '加州':
        return 'United States'
    if s == '美国缅因州':
        return 'United States'
chandi['index'] = chandi['index'].map(countryName)
country = list(chandi['index'])
v = list(chandi['原产地'])

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", [list(z) for z in zip(country, v)], "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title=""),
        visualmap_opts=opts.VisualMapOpts(is_show=False),
    )
)
c.render('../output/原产地分布地图.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="d0c8f70c32374bf59663057e1b488201" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_d0c8f70c32374bf59663057e1b488201 = echarts.init(
#                     document.getElementById('d0c8f70c32374bf59663057e1b488201'), 'light', {renderer: 'canvas'});
#                 var option_d0c8f70c32374bf59663057e1b488201 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "United Kingdom",
#                     "value": 7
#                 },
#                 {
#                     "name": "United States",
#                     "value": 6
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 2
#                 },
#                 {
#                     "value": 1
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 1
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 1
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 1
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 1
#                 },
#                 {
#                     "name": "United States",
#                     "value": 1
#                 },
#                 {
#                     "name": "United States",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": false,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_d0c8f70c32374bf59663057e1b488201.setOption(option_d0c8f70c32374bf59663057e1b488201);
#         });
#     </script>

# %% [markdown]
# # 外观描述词云

# %%
cat_kind['整体'] = cat_kind['整体'].astype(str)
zhengti = list(cat_kind['整体'])
zhengti = ','.join(zhengti)
cat_kind['毛发'] = cat_kind['毛发'].astype(str)
hair = list(cat_kind['毛发'])
hair = ','.join(hair)
cat_kind['颜色'] = cat_kind['颜色'].astype(str)
color = list(cat_kind['颜色'])
color = ','.join(color)
cat_kind['头部'] = cat_kind['头部'].astype(str)
head = list(cat_kind['头部'])
head = ','.join(head)
cat_kind['眼睛'] = cat_kind['眼睛'].astype(str)
eye = list(cat_kind['眼睛'])
eye = ','.join(eye)
cat_kind['耳朵'] = cat_kind['耳朵'].astype(str)
ear = list(cat_kind['耳朵'])
ear = ','.join(ear)
cat_kind['鼻子'] = cat_kind['鼻子'].astype(str)
nose = list(cat_kind['鼻子'])
nose = ','.join(nose)
cat_kind['尾巴'] = cat_kind['尾巴'].astype(str)
tail = list(cat_kind['尾巴'])
tail = ','.join(tail)
cat_kind['胸部'] = cat_kind['胸部'].astype(str)
nest = list(cat_kind['胸部'])
nest = ','.join(nest)
cat_kind['颈部'] = cat_kind['颈部'].astype(str)
neck = list(cat_kind['颈部'])
neck = ','.join(neck)
cat_kind['前驱'] = cat_kind['前驱'].astype(str)
fontfoot = list(cat_kind['前驱'])
fontfoot = ','.join(fontfoot)
cat_kind['后驱'] = cat_kind['后驱'].astype(str)
rearfoot = list(cat_kind['后驱'])
rearfoot = ','.join(rearfoot)

txt = zhengti + hair + color + head + eye + ear + nose + tail + nest + neck + fontfoot + rearfoot
txt = txt.replace('nan','')

# %%
import stylecloud 

stylecloud.gen_stylecloud(text=txt, collocations=False,
                          font_path=r'‪C:\Windows\Fonts\msyh.ttc',
                          icon_name='fas fa-cat',
                          output_name='../output/外观描述词云.png')

# %% [markdown]
# # 交易分布地图

# %%
cat_info['地区'] = cat_info['地区'].astype(str)
cat_info['province'] = cat_info['地区'].map(lambda s: s.split('/')[0])
pv = cat_info['province'].value_counts().reset_index()

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", [list(z) for z in zip(list(pv['index']), list(pv['province']))], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="猫猫售卖省份分布"),
        visualmap_opts=opts.VisualMapOpts(max_=16500, is_piecewise=True),
    )
)
c.render('../output/猫猫售卖省份分布.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6a497c1477b94e4c9e333baa72894e0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_6a497c1477b94e4c9e333baa72894e0f = echarts.init(
#                     document.getElementById('6a497c1477b94e4c9e333baa72894e0f'), 'light', {renderer: 'canvas'});
#                 var option_6a497c1477b94e4c9e333baa72894e0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 17142
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 16273
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 16187
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 15293
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 11140
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 10676
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 10015
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 8628
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 7928
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 7673
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 7607
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 7422
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 6710
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 5580
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 4936
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 4484
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 4454
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 4025
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 3930
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 3783
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3595
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3564
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3537
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3505
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 3463
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 3259
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 3111
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 2497
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2329
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2110
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1546
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 274
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 201
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 137
#                 },
#                 {
#                     "name": "nan",
#                     "value": 9
#                 },
#                 {
#                     "name": "l",
#                     "value": 4
#                 },
#                 {
#                     "name": "tml",
#                     "value": 3
#                 },
#                 {
#                     "name": "html",
#                     "value": 3
#                 },
#                 {
#                     "name": "92.html",
#                     "value": 2
#                 },
#                 {
#                     "name": "96.html",
#                     "value": 2
#                 },
#                 {
#                     "name": "hp?",
#                     "value": 2
#                 },
#                 {
#                     "name": "aoyi.com",
#                     "value": 1
#                 },
#                 {
#                     "name": "ng_451447.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "nxiangqing_519643.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "qing_567239.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "7276.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "476.html",
#                     "value": 1
#                 },
#                 {
#                     "name": ":",
#                     "value": 1
#                 },
#                 {
#                     "name": "ndex.php?",
#                     "value": 1
#                 },
#                 {
#                     "name": "_298130.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "?\u770b\u732b\u54aa",
#                     "value": 1
#                 },
#                 {
#                     "name": "096.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "_340691.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "0630.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "56.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "angqing_537543.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "_318564.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "omijiaoyi.com",
#                     "value": 1
#                 },
#                 {
#                     "name": "2.html",
#                     "value": 1
#                 },
#                 {
#                     "name": "yi.com",
#                     "value": 1
#                 },
#                 {
#                     "name": "ing_291783.html",
#                     "value": 1
#                 },

# %% [markdown]
# # 交易品种占比树状图

# %%
from pyecharts import options as opts
from pyecharts.charts import TreeMap

pingzhong = cat_info['品种'].value_counts().reset_index()
data = [{'value':i[1],'name':i[0]} for i in zip(list(pingzhong['index']),list(pingzhong['品种']))]

c = (
    TreeMap(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add("", data)
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
    .set_series_opts(label_opts=opts.LabelOpts(position="inside"))
)
c.render('../output/交易品种占比.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b292ac639f54441da61dbfb1073b2270" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b292ac639f54441da61dbfb1073b2270 = echarts.init(
#                     document.getElementById('b292ac639f54441da61dbfb1073b2270'), 'light', {renderer: 'canvas'});
#                 var option_b292ac639f54441da61dbfb1073b2270 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "treemap",
#             "data": [
#                 {
#                     "value": 24809,
#                     "name": "\u6a58\u732b"
#                 },
#                 {
#                     "value": 19839,
#                     "name": "\u52a0\u83f2\u732b"
#                 },
#                 {
#                     "value": 15746,
#                     "name": "\u5e03\u5076\u732b"
#                 },
#                 {
#                     "value": 15288,
#                     "name": "\u82f1\u77ed\u84dd\u767d"
#                 },
#                 {
#                     "value": 14578,
#                     "name": "\u66b9\u7f57\u732b"
#                 },
#                 {
#                     "value": 12491,
#                     "name": "\u65e0\u6bdb\u732b"
#                 },
#                 {
#                     "value": 11704,
#                     "name": "\u9ad8\u5730\u6298\u8033\u732b"
#                 },
#                 {
#                     "value": 11587,
#                     "name": "\u91d1\u6e10\u5c42"
#                 },
#                 {
#                     "value": 11008,
#                     "name": "\u82f1\u77ed\u84dd\u732b"
#                 },
#                 {
#                     "value": 10391,
#                     "name": "\u6ce2\u65af\u732b"
#                 },
#                 {
#                     "value": 7905,
#                     "name": "\u5b5f\u4e70\u732b"
#                 },
#                 {
#                     "value": 7772,
#                     "name": "\u82cf\u683c\u5170\u6298\u8033\u732b"
#                 },
#                 {
#                     "value": 7728,
#                     "name": "\u94f6\u6e10\u5c42"
#                 },
#                 {
#                     "value": 7458,
#                     "name": "\u66fc\u57fa\u5eb7\u77ee\u811a\u732b"
#                 },
#                 {
#                     "value": 6600,
#                     "name": "\u91d1\u5409\u62c9\u732b"
#                 },
#                 {
#                     "value": 6522,
#                     "name": "\u7f05\u56e0\u732b"
#                 },
#                 {
#                     "value": 5127,
#                     "name": "\u82f1\u56fd\u77ed\u6bdb\u732b"
#                 },
#                 {
#                     "value": 4612,
#                     "name": "\u963f\u6bd4\u897f\u5c3c\u4e9a\u732b"
#                 },
#                 {
#                     "value": 2925,
#                     "name": "\u5f02\u56fd\u77ed\u6bdb\u732b"
#                 },
#                 {
#                     "value": 1979,
#                     "name": "\u5b5f\u52a0\u62c9\u8c79\u732b"
#                 },
#                 {
#                     "value": 945,
#                     "name": "\u7f8e\u56fd\u77ed\u6bdb\u732b"
#                 }
#             ],
#             "width": "80%",
#             "height": "80%",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "upperlabel": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "drillDownIcon": "\u25b6",
#             "roam": true,
#             "nodeClick": "zoomToNode",
#             "zoomToNodeRatio": 0.1024,
#             "colorMappingBy": "index",
#             "visibleMin": 10,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b292ac639f54441da61dbfb1073b2270.setOption(option_b292ac639f54441da61dbfb1073b2270);
#         });
#     </script>

# %% [markdown]
# # 每种品种平均价格排名，条形图

# %%
price = cat_info.groupby('品种').mean()['价格'].reset_index()
price['价格'] = round(price['价格'],0)
price = price.sort_values(by='价格')

# %%
from pyecharts import options as opts
from pyecharts.charts import PictorialBar
from pyecharts.globals import SymbolType

location = list(price['品种'])
values = list(price['价格'])

c = (
    PictorialBar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(location)
    .add_yaxis(
        "",
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat="fixed",
        symbol_offset=[0, 0],
        is_symbol_clip=True,
        symbol=SymbolType.ROUND_RECT,
    )
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="均价排名"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=False),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(opacity=0),
            
            ),
        ),
    )
    .set_series_opts(
        label_opts=opts.LabelOpts(position='insideRight')
    )
)
c.render('../output/均价排名.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cbcad51e93014203add9caf5abc8b722" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cbcad51e93014203add9caf5abc8b722 = echarts.init(
#                     document.getElementById('cbcad51e93014203add9caf5abc8b722'), 'light', {renderer: 'canvas'});
#                 var option_cbcad51e93014203add9caf5abc8b722 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 851.0,
#                 977.0,
#                 997.0,
#                 1068.0,
#                 1089.0,
#                 1097.0,
#                 1123.0,
#                 1131.0,
#                 1143.0,
#                 1190.0,
#                 1191.0,
#                 1195.0,
#                 1195.0,
#                 1245.0,
#                 1255.0,
#                 1257.0,
#                 1274.0,
#                 1393.0,
#                 1436.0,
#                 1575.0,
#                 1630.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "insideRight",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5b5f\u52a0\u62c9\u8c79\u732b",
#                 "\u6a58\u732b",
#                 "\u7f8e\u56fd\u77ed\u6bdb\u732b",
#                 "\u91d1\u5409\u62c9\u732b",
#                 "\u82cf\u683c\u5170\u6298\u8033\u732b",
#                 "\u94f6\u6e10\u5c42",
#                 "\u66fc\u57fa\u5eb7\u77ee\u811a\u732b",
#                 "\u5f02\u56fd\u77ed\u6bdb\u732b",
#                 "\u52a0\u83f2\u732b",
#                 "\u82f1\u77ed\u84dd\u767d",
#                 "\u82f1\u56fd\u77ed\u6bdb\u732b",
#                 "\u6ce2\u65af\u732b",
#                 "\u963f\u6bd4\u897f\u5c3c\u4e9a\u732b",
#                 "\u82f1\u77ed\u84dd\u732b",
#                 "\u65e0\u6bdb\u732b",
#                 "\u91d1\u6e10\u5c42",
#                 "\u5b5f\u4e70\u732b",
#                 "\u9ad8\u5730\u6298\u8033\u732b",
#                 "\u66b9\u7f57\u732b",
#                 "\u5e03\u5076\u732b",
#                 "\u7f05\u56e0\u732b"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5747\u4ef7\u6392\u540d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cbcad51e93014203add9caf5abc8b722.setOption(option_cbcad51e93014203add9caf5abc8b722);
#         });
#     </script>

# %% [markdown]
# # 年龄分布，柱状图

# %%
cat_info['年龄'] = cat_info['年龄'].astype(str)
age = cat_info['年龄'].map(lambda x: x.replace('个月','')).reset_index()
def ages(s):
    if s == 'nan':
        return s
    s = int(s)
    if 1 <= s < 3: 
        return '1-3个月'
    if 3 <= s < 6: 
        return '3-6个月'
    if 6 <= s < 9:
        return '6-9个月'
    if 9 <= s < 12 :
        return '9-12个月'
    if s >= 12:
        return '1年以上'
age['age'] = age['年龄'].map(ages)
age = age['age'].value_counts().reset_index()
age = age[age['index'] != 'nan']
age
# Out:
#     index     age
# 0   3-6个月  115288
# 1   1-3个月   69343
# 2   6-9个月   18239
# 3  9-12个月    4139
# 5    1年以上       5

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

x = ['1-3个月','3-6个月','6-9个月','9-12个月','1年以上']
y = [69343,115288,18239,4139,5]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(x)
    .add_yaxis('', y)
    .set_global_opts(title_opts=opts.TitleOpts(title="猫龄分布"))
)
c.render('../output/猫龄分布.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a3c048503622439e836f5e02bb1e0b15" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a3c048503622439e836f5e02bb1e0b15 = echarts.init(
#                     document.getElementById('a3c048503622439e836f5e02bb1e0b15'), 'light', {renderer: 'canvas'});
#                 var option_a3c048503622439e836f5e02bb1e0b15 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 69343,
#                 115288,
#                 18239,
#                 4139,
#                 5
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1-3\u4e2a\u6708",
#                 "3-6\u4e2a\u6708",
#                 "6-9\u4e2a\u6708",
#                 "9-12\u4e2a\u6708",
#                 "1\u5e74\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u732b\u9f84\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a3c048503622439e836f5e02bb1e0b15.setOption(option_a3c048503622439e836f5e02bb1e0b15);
#         });
#     </script>

# %% [markdown]
# # 浏览次数是否跟价格成正比，散点图

# %%
view = cat_info['浏览次数']
money = cat_info['价格']

import pyecharts.options as opts
from pyecharts.charts import Scatter


data.sort(key=lambda x: x[0])
x_data = list(view)[:1000]
y_data = list(money)[:1000]

c = (
    Scatter(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="",
        y_axis=y_data,
        symbol_size=20,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_series_opts()
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(
            type_="value", 
            splitline_opts=opts.SplitLineOpts(is_show=True),
            name='浏览次数'
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
            name='价格'
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
    )
)
c.render('../output/浏览次数&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ad611c65445446bbafa963c41580cf5f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ad611c65445446bbafa963c41580cf5f = echarts.init(
#                     document.getElementById('ad611c65445446bbafa963c41580cf5f'), 'light', {renderer: 'canvas'});
#                 var option_ad611c65445446bbafa963c41580cf5f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 20,
#             "data": [
#                 [
#                     255.0,
#                     2100.0
#                 ],
#                 [
#                     427.0,
#                     1300.0
#                 ],
#                 [
#                     242.0,
#                     200.0
#                 ],
#                 [
#                     406.0,
#                     1300.0
#                 ],
#                 [
#                     220.0,
#                     400.0
#                 ],
#                 [
#                     492.0,
#                     1500.0
#                 ],
#                 [
#                     211.0,
#                     300.0
#                 ],
#                 [
#                     241.0,
#                     300.0
#                 ],
#                 [
#                     238.0,
#                     1900.0
#                 ],
#                 [
#                     252.0,
#                     1200.0
#                 ],
#                 [
#                     237.0,
#                     500.0
#                 ],
#                 [
#                     231.0,
#                     1300.0
#                 ],
#                 [
#                     203.0,
#                     2100.0
#                 ],
#                 [
#                     229.0,
#                     300.0
#                 ],
#                 [
#                     258.0,
#                     1300.0
#                 ],
#                 [
#                     312.0,
#                     500.0
#                 ],
#                 [
#                     289.0,
#                     800.0
#                 ],
#                 [
#                     195.0,
#                     1000.0
#                 ],
#                 [
#                     205.0,
#                     600.0
#                 ],
#                 [
#                     318.0,
#                     1800.0
#                 ],
#                 [
#                     253.0,
#                     200.0
#                 ],
#                 [
#                     243.0,
#                     1600.0
#                 ],
#                 [
#                     209.0,
#                     300.0
#                 ],
#                 [
#                     255.0,
#                     1200.0
#                 ],
#                 [
#                     251.0,
#                     1300.0
#                 ],
#                 [
#                     249.0,
#                     600.0
#                 ],
#                 [
#                     211.0,
#                     1500.0
#                 ],
#                 [
#                     266.0,
#                     800.0
#                 ],
#                 [
#                     257.0,
#                     3000.0
#                 ],
#                 [
#                     191.0,
#                     500.0
#                 ],
#                 [
#                     191.0,
#                     1200.0
#                 ],
#                 [
#                     238.0,
#                     600.0
#                 ],
#                 [
#                     211.0,
#                     1300.0
#                 ],
#                 [
#                     254.0,
#                     1500.0
#                 ],
#                 [
#                     197.0,
#                     2500.0
#                 ],
#                 [
#                     199.0,
#                     600.0
#                 ],
#                 [
#                     202.0,
#                     1900.0
#                 ],
#                 [
#                     274.0,
#                     200.0
#                 ],
#                 [
#                     220.0,
#                     400.0
#                 ],
#                 [
#                     219.0,
#                     2500.0
#                 ],
#                 [
#                     196.0,
#                     1000.0
#                 ],
#                 [
#                     225.0,
#                     500.0
#                 ],
#                 [
#                     397.0,
#                     1700.0
#                 ],
#                 [
#                     242.0,
#                     1300.0
#                 ],
#                 [
#                     545.0,
#                     1000.0
#                 ],
#                 [
#                     200.0,
#                     900.0
#                 ],
#                 [
#                     194.0,
#                     300.0
#                 ],
#                 [
#                     351.0,
#                     1000.0
#                 ],
#                 [
#                     154.0,
#                     1100.0
#                 ],
#                 [
#                     215.0,
#                     600.0
#                 ],
#                 [
#                     236.0,
#                     200.0
#                 ],
#                 [
#                     207.0,
#                     300.0
#                 ],
#                 [
#                     282.0,
#                     1400.0
#                 ],
#                 [
#                     201.0,
#                     400.0
#                 ],
#                 [
#                     298.0,
#                     1200.0
#                 ],
#                 [
#                     189.0,
#                     2100.0
#                 ],
#                 [
#                     279.0,
#                     600.0
#                 ],
#                 [
#                     398.0,
#                     1700.0
#                 ],
#                 [
#                     375.0,
#                     300.0
#                 ],
#                 [
#                     310.0,
#                     1300.0
#                 ],
#                 [
#                     190.0,
#                     600.0
#                 ],
#                 [
#                     258.0,
#                     1800.0
#                 ],
#                 [
#                     196.0,
#                     1900.0
#                 ],
#                 [
#                     279.0,
#                     400.0
#                 ],
#                 [
#                     196.0,
#                     1300.0
#                 ],
#                 [
#                     353.0,
#                     500.0
#                 ],
#                 [
#                     207.0,
#                     300.0
#                 ],
#                 [
#                     244.0,
#                     2300.0
#                 ],
#                 [
#                     223.0,
#                     600.0
#                 ],
#                 [
#                     344.0,
#                     600.0
#                 ],
#                 [
#                     279.0,
#                     1000.0
#                 ],
#                 [
#                     202.0,
#                     1000.0
#                 ],
#                 [
#                     246.0,
#                     2100.0
#                 ],
#                 [
#                     257.0,
#                     600.0
#                 ],
#                 [
#                     236.0,
#                     600.0
#                 ],
#                 [
#                     180.0,
#                     300.0
#                 ],
#                 [
#                     229.0,
#                     1300.0
#                 ],
#                 [
#                     186.0,
#                     400.0
#                 ],
#                 [

# %% [markdown]
# # 价格是否与年龄有关，箱型图

# %%
a_p = cat_info[['价格','年龄']]
a_p['年龄'] = a_p['年龄'].map(lambda x: x.replace('个月',''))
def ages(s):
    if s == 'nan':
        return s
    s = int(s)
    if 1 <= s < 3: 
        return '1-3个月'
    if 3 <= s < 6: 
        return '3-6个月'
    if 6 <= s < 9:
        return '6-9个月'
    if 9 <= s < 12 :
        return '9-12个月'
    if s >= 12:
        return '1年以上'
a_p['age'] = a_p['年龄'].map(ages)
a_p.head()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        价格 年龄    age
# 0  2100.0  3  3-6个月
# 1  1300.0  2  1-3个月
# 2   200.0  4  3-6个月
# 3  1300.0  3  3-6个月
# 4   400.0  3  3-6个月

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    list(a_p[a_p['age'] == '1-3个月']['价格']),
    list(a_p[a_p['age'] == '3-6个月']['价格']),
    list(a_p[a_p['age'] == '6-9个月']['价格']),
    list(a_p[a_p['age'] == '9-12个月']['价格']),
    list(a_p[a_p['age'] == '1年以上']['价格'])
]

c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
c.add_xaxis(["1-3个月", "3-6个月",'6-9个月','9-12个月','1年以上'])
c.add_yaxis("喵喵", c.prepare_data(v1))
c.set_global_opts(title_opts=opts.TitleOpts(title="猫龄&价格"))
c.render('../output/猫龄&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1d5cc5e0709242b88efb5dd2c545ad3e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1d5cc5e0709242b88efb5dd2c545ad3e = echarts.init(
#                     document.getElementById('1d5cc5e0709242b88efb5dd2c545ad3e'), 'light', {renderer: 'canvas'});
#                 var option_1d5cc5e0709242b88efb5dd2c545ad3e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u55b5\u55b5",
#             "data": [
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     500.0,
#                     600.0,
#                     800.0,
#                     1700.0,
#                     2600.0
#                 ],
#                 [
#                     1400.0,
#                     1600.0,
#                     1700.0,
#                     1900.0,
#                     2300.0
#                 ],
#                 [
#                     1300.0,
#                     1300.0,
#                     1400.0,
#                     1650.0,
#                     1700.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u55b5\u55b5"
#             ],
#             "selected": {
#                 "\u55b5\u55b5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1-3\u4e2a\u6708",
#                 "3-6\u4e2a\u6708",
#                 "6-9\u4e2a\u6708",
#                 "9-12\u4e2a\u6708",
#                 "1\u5e74\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u732b\u9f84&\u4ef7\u683c",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1d5cc5e0709242b88efb5dd2c545ad3e.setOption(option_1d5cc5e0709242b88efb5dd2c545ad3e);
#         });
#     </script>

# %% [markdown]
# # 价格是否与预防有关，箱型图

# %%
yufang = cat_info[['价格','预防']]
yufang['预防'].unique()
# Out:
# array(['2针疫苗', '1针疫苗', '3针疫苗', nan, '0针疫苗'], dtype=object)

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    list(yufang[yufang['预防'] == '0针疫苗']['价格']),
    list(yufang[yufang['预防'] == '1针疫苗']['价格']),
    list(yufang[yufang['预防'] == '2针疫苗']['价格']),
    list(yufang[yufang['预防'] == '3针疫苗']['价格']),
]

c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
c.add_xaxis(["0针疫苗", "1针疫苗",'2针疫苗','3针疫苗'])
c.add_yaxis("喵喵", c.prepare_data(v1))
c.set_global_opts(title_opts=opts.TitleOpts(title="防疫&价格"))
c.render('../output/防疫&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d7b5546491ac43e9ba1043328c2c884f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d7b5546491ac43e9ba1043328c2c884f = echarts.init(
#                     document.getElementById('d7b5546491ac43e9ba1043328c2c884f'), 'light', {renderer: 'canvas'});
#                 var option_d7b5546491ac43e9ba1043328c2c884f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u55b5\u55b5",
#             "data": [
#                 [
#                     1000.0,
#                     1300.0,
#                     1400.0,
#                     1725.0,
#                     1900.0
#                 ],
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     200.0,
#                     800.0,
#                     1500.0,
#                     1800.0,
#                     3000.0
#                 ],
#                 [
#                     200.0,
#                     400.0,
#                     600.0,
#                     1000.0,
#                     3000.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u55b5\u55b5"
#             ],
#             "selected": {
#                 "\u55b5\u55b5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u9488\u75ab\u82d7",
#                 "1\u9488\u75ab\u82d7",
#                 "2\u9488\u75ab\u82d7",
#                 "3\u9488\u75ab\u82d7"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u9632\u75ab&\u4ef7\u683c",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d7b5546491ac43e9ba1043328c2c884f.setOption(option_d7b5546491ac43e9ba1043328c2c884f);
#         });
#     </script>

# %% [markdown]
# # 价格是否与异地运费有关，箱型图

# %%
yunfei = cat_info[['价格','异地运费']]

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    list(yunfei[yunfei['异地运费'] == '包运费！签协议！']['价格']),
    list(yunfei[yunfei['异地运费'] == '不包邮！']['价格']),
]

c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
c.add_xaxis(["包运费！签协议！", "不包邮！"])
c.add_yaxis("喵喵", c.prepare_data(v1))
c.set_global_opts(title_opts=opts.TitleOpts(title="运费&价格"))
c.render('../output/运费&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="02db232750674136a903bc0c462ebeae" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_02db232750674136a903bc0c462ebeae = echarts.init(
#                     document.getElementById('02db232750674136a903bc0c462ebeae'), 'light', {renderer: 'canvas'});
#                 var option_02db232750674136a903bc0c462ebeae = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u55b5\u55b5",
#             "data": [
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     1000.0,
#                     1300.0,
#                     1400.0,
#                     1725.0,
#                     1900.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u55b5\u55b5"
#             ],
#             "selected": {
#                 "\u55b5\u55b5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5305\u8fd0\u8d39\uff01\u7b7e\u534f\u8bae\uff01",
#                 "\u4e0d\u5305\u90ae\uff01"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8fd0\u8d39&\u4ef7\u683c",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_02db232750674136a903bc0c462ebeae.setOption(option_02db232750674136a903bc0c462ebeae);
#         });
#     </script>

# %% [markdown]
# # 价格是否与是否纯种有关，箱型图

# %%
pure = cat_info[['价格','是否纯种']]
pure['是否纯种'].unique()
# Out:
# array(['是', nan, '否'], dtype=object)

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    list(pure[pure['是否纯种'] == '是']['价格']),
    list(pure[pure['是否纯种'] == '否']['价格']),
]

c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
c.add_xaxis(["是", "否"])
c.add_yaxis("喵喵", c.prepare_data(v1))
c.set_global_opts(title_opts=opts.TitleOpts(title="纯种&价格"))
c.render('../output/纯种&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3e56d51ac47f4b49b0f7d747b985aa60" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3e56d51ac47f4b49b0f7d747b985aa60 = echarts.init(
#                     document.getElementById('3e56d51ac47f4b49b0f7d747b985aa60'), 'light', {renderer: 'canvas'});
#                 var option_3e56d51ac47f4b49b0f7d747b985aa60 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u55b5\u55b5",
#             "data": [
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     1000.0,
#                     1300.0,
#                     1400.0,
#                     1725.0,
#                     1900.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u55b5\u55b5"
#             ],
#             "selected": {
#                 "\u55b5\u55b5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u662f",
#                 "\u5426"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7eaf\u79cd&\u4ef7\u683c",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3e56d51ac47f4b49b0f7d747b985aa60.setOption(option_3e56d51ac47f4b49b0f7d747b985aa60);
#         });
#     </script>

# %% [markdown]
# # 价格是否与能否视频有关，箱型图

# %%
vedio = cat_info[['价格','能否视频']]
vedio['能否视频'].unique()
# Out:
# array(['可视频看猫咪', nan, '不可视频看猫咪'], dtype=object)

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    list(vedio[vedio['能否视频'] == '可视频看猫咪']['价格']),
    list(vedio[vedio['能否视频'] == '不可视频看猫咪']['价格']),
]

c = Boxplot(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
c.add_xaxis(["可视频看猫咪", "不可视频看猫咪"])
c.add_yaxis("喵喵", c.prepare_data(v1))
c.set_global_opts(title_opts=opts.TitleOpts(title="可看视频&价格"))
c.render('../output/可看视频&价格.html')
c.render_notebook()
# Out:
# D:\programming\dev_env\anaconda\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="769b731f2dcf4cf786fee6ab8b728fae" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_769b731f2dcf4cf786fee6ab8b728fae = echarts.init(
#                     document.getElementById('769b731f2dcf4cf786fee6ab8b728fae'), 'light', {renderer: 'canvas'});
#                 var option_769b731f2dcf4cf786fee6ab8b728fae = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u55b5\u55b5",
#             "data": [
#                 [
#                     200.0,
#                     600.0,
#                     1300.0,
#                     1700.0,
#                     3000.0
#                 ],
#                 [
#                     1000.0,
#                     1300.0,
#                     1400.0,
#                     1725.0,
#                     1900.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u55b5\u55b5"
#             ],
#             "selected": {
#                 "\u55b5\u55b5": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u89c6\u9891\u770b\u732b\u54aa",
#                 "\u4e0d\u53ef\u89c6\u9891\u770b\u732b\u54aa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u53ef\u770b\u89c6\u9891&\u4ef7\u683c",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_769b731f2dcf4cf786fee6ab8b728fae.setOption(option_769b731f2dcf4cf786fee6ab8b728fae);
#         });
#     </script>
